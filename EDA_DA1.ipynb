# %% [markdown]
# <a href="https://colab.research.google.com/github/jayaasuthersen/JayaaSuthersen/blob/main/EDA_DA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Load the covid-data.csv and explore Dimension, Summary, Data Handling, Data Cleaning, Univariate, Bivariate and Multivariate Analysis (Maximum of all the possibilities).

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('covid-data.csv')

# Dimension
print("Dataset Dimension:")
print(df.shape)  # Rows and columns

# Summary
print("\nDataset Summary:")
print(df.info()) # Data types and non-null counts
print(df.describe())  # Statistical summary of numerical features


# Data Handling
# (Example: Handling missing values, converting data types)
# Replace this with your specific data handling steps
# df['column_name'] = df['column_name'].fillna(0)
# df['date_column'] = pd.to_datetime(df['date_column'])


# Data Cleaning
# (Example: Removing duplicates, correcting inconsistencies)
# df.drop_duplicates(inplace=True)
# df['column_name'] = df['column_name'].replace({'old_value': 'new_value'})


# Univariate Analysis
# Analyze each feature individually (e.g., histograms, boxplots)
# Replace with your desired analysis for specific columns
plt.figure(figsize=(10, 6))
plt.hist(df['new_cases'], bins=20)
plt.title("Histogram of New Cases")
plt.xlabel("New Cases")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['new_deaths'])
plt.title("Boxplot of New Deaths")
plt.show()


# Bivariate Analysis
# Analyze relationships between two features (e.g., scatter plots, correlation matrices)
# Replace with your analysis for specific pairs of columns
plt.figure(figsize=(10, 6))
sns.scatterplot(x='new_cases', y='new_deaths', data=df)
plt.title("Scatter Plot of New Cases vs. New Deaths")
plt.show()

correlation_matrix = df[['new_cases', 'new_deaths', 'total_cases', 'total_deaths']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# Multivariate Analysis
# Analyze relationships between multiple features
# (e.g., pair plots, 3D plots)
# Replace with your analysis for specific sets of columns
sns.pairplot(df[['new_cases', 'new_deaths', 'total_cases', 'total_deaths']], hue='location', diag_kind='kde')
plt.show()



# You can also perform further analyses depending on your specific needs:
# Time series analysis (if you have a date column)
# Geographical analysis (if you have location data)
# Clustering analysis
# Regression analysis
# Out:
# Dataset Dimension:
# (5818, 67)
#
# Dataset Summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5818 entries, 0 to 5817
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    5818 non-null   object
#  1   continent                                   5818 non-null   object
#  2   location                                    5818 non-null   object
#  3   date                                        5818 non-null   object
#  4   total_cases                                 5818 non-null   int64
#  5   new_cases                                   5818 non-null   int64
#  6   new_cases_smoothed                          5788 non-null   float64
#  7   total_deaths                                5638 non-null   float64
#  8   new_deaths                                  5627 non-null   float64
# ...
